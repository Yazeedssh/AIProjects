# %%
# !pip install roboflow

# %%
# !pip install ultralytics==8.0.196

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Z66cZDsEI5dgi7ds4OqD")
project = rf.workspace("tayma").project("plant_diseases-zempm")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import os
os.chdir("/content/drive/MyDrive/Colab_Notebooks")

# %%
# !mkdir YOLOv8n_capstone_PantVillage_tuned2

# %%
# %cd YOLOv8n_capstone_PantVillage_tuned2
# Out:
# /content/drive/MyDrive/Colab_Notebooks/YOLOv8n_capstone_PantVillage_tuned2

# %%
# !yolo detect train model=yolov8s.pt data=/content/plant_diseases-1/data.yaml name=yolov8_plantvillage_tuned device=0 epochs=50 patience=10 workers=2 batch=64 lr0=0.001 momentum=0.9 weight_decay=0.0001 warmup_epochs=10 warmup_momentum=0.5 warmup_bias_lr=0.1 optimizer=AdamW
# Out:
# New https://pypi.org/project/ultralytics/8.2.18 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
